# %% [markdown]
# <a href="https://colab.research.google.com/github/agrawalshubham665/JP-Morgan-Quant/blob/main/BucketingFICOScores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Load Libreries
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib import pyplot
from scipy.stats import norm
import datetime as dt

# %%
# Import data
Loans_df = pd.read_csv("/content/Loan_Data.csv")

# %%
Loans_df
# Out:
#       customer_id  credit_lines_outstanding  loan_amt_outstanding  \
# 0         8153374                         0           5221.545193
# 1         7442532                         5           1958.928726
# 2         2256073                         0           3363.009259
# 3         4885975                         0           4766.648001
# 4         4700614                         1           1345.827718
# ...           ...                       ...                   ...
# 9995      3972488                         0           3033.647103
# 9996      6184073                         1           4146.239304
# 9997      6694516                         2           3088.223727
# 9998      3942961                         0           3288.901666
# 9999      5533570                         1           1917.652480
#
#       total_debt_outstanding       income  years_employed  fico_score  default
# 0                3915.471226  78039.38546               5         605        0
# 1                8228.752520  26648.43525               2         572        1
# 2                2027.830850  65866.71246               4         602        0
# 3                2501.730397  74356.88347               5         612        0
# 4                1768.826187  23448.32631               6         631        0
# ...                      ...          ...             ...         ...      ...
# 9995             2553.733144  42691.62787               5         697        0
# 9996             5458.163525  79969.50521               8         615        0
# 9997             4813.090925  38192.67591               5         596        0
# 9998             1043.099660  50929.37206               2         647        0
# 9999             3050.248203  30611.62821               6         757        0
#
# [10000 rows x 8 columns]

# %%
Loans_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               10000 non-null  int64
#  1   credit_lines_outstanding  10000 non-null  int64
#  2   loan_amt_outstanding      10000 non-null  float64
#  3   total_debt_outstanding    10000 non-null  float64
#  4   income                    10000 non-null  float64
#  5   years_employed            10000 non-null  int64
#  6   fico_score                10000 non-null  int64
#  7   default                   10000 non-null  int64
# dtypes: float64(3), int64(5)
# memory usage: 625.1 KB

# %%
Loans_df.describe()
# Out:
#         customer_id  credit_lines_outstanding  loan_amt_outstanding  \
# count  1.000000e+04              10000.000000          10000.000000
# mean   4.974577e+06                  1.461200           4159.677034
# std    2.293890e+06                  1.743846           1421.399078
# min    1.000324e+06                  0.000000             46.783973
# 25%    2.977661e+06                  0.000000           3154.235371
# 50%    4.989502e+06                  1.000000           4052.377228
# 75%    6.967210e+06                  2.000000           5052.898103
# max    8.999789e+06                  5.000000          10750.677810
#
#        total_debt_outstanding         income  years_employed    fico_score  \
# count            10000.000000   10000.000000    10000.000000  10000.000000
# mean              8718.916797   70039.901401        4.552800    637.557700
# std               6627.164762   20072.214143        1.566862     60.657906
# min                 31.652732    1000.000000        0.000000    408.000000
# 25%               4199.836020   56539.867903        3.000000    597.000000
# 50%               6732.407217   70085.826330        5.000000    638.000000
# 75%              11272.263740   83429.166133        6.000000    679.000000
# max              43688.784100  148412.180500       10.000000    850.000000
#
#             default
# count  10000.000000
# mean       0.185100
# std        0.388398
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %% [markdown]
# # Rating map

# %% [markdown]
# Creating a rating map that maps the FICO score of the borrowers to a rating where a lower rating signifies a better credit score.
# The process of doing this is known as quantization.
# Creating six buckets for FICO scores ranging from 300 to 850.

# %%
d = {range(800,851):1,range(750,800):2,range(700,750):3,
     range(650,700):4,range(600,650):5,range(300,600):6 }

# %%
d
# Out:
# {range(800, 851): 1,
#  range(750, 800): 2,
#  range(700, 750): 3,
#  range(650, 700): 4,
#  range(600, 650): 5,
#  range(300, 600): 6}

# %%
Loans_df['Rating'] = Loans_df['fico_score'].apply(lambda x: next((v for k, v in d.items() if x in k), 0))

# %%
Loans_df.groupby('fico_score')['default']

# %%
Loans_df
# Out:
#       customer_id  credit_lines_outstanding  loan_amt_outstanding  \
# 0         8153374                         0           5221.545193
# 1         7442532                         5           1958.928726
# 2         2256073                         0           3363.009259
# 3         4885975                         0           4766.648001
# 4         4700614                         1           1345.827718
# ...           ...                       ...                   ...
# 9995      3972488                         0           3033.647103
# 9996      6184073                         1           4146.239304
# 9997      6694516                         2           3088.223727
# 9998      3942961                         0           3288.901666
# 9999      5533570                         1           1917.652480
#
#       total_debt_outstanding       income  years_employed  fico_score  \
# 0                3915.471226  78039.38546               5         605
# 1                8228.752520  26648.43525               2         572
# 2                2027.830850  65866.71246               4         602
# 3                2501.730397  74356.88347               5         612
# 4                1768.826187  23448.32631               6         631
# ...                      ...          ...             ...         ...
# 9995             2553.733144  42691.62787               5         697
# 9996             5458.163525  79969.50521               8         615
# 9997             4813.090925  38192.67591               5         596
# 9998             1043.099660  50929.37206               2         647
# 9999             3050.248203  30611.62821               6         757
#
#       default  Rating
# 0           0       5
# 1           1       6
# 2           0       5
# 3           0       5
# 4           0       5
# ...       ...     ...
# 9995        0       4
# 9996        0       5
# 9997        0       6
# 9998        0       5
# 9999        0       2
#
# [10000 rows x 9 columns]

# %%
plt.figure(figsize=(9,5))
sns.countplot(x=Loans_df['Rating'],hue=Loans_df['default'])
plt.tight_layout()

# %%
Loans_df.groupby('Rating')['default'].value_counts().sort_values()
# Out:
# Rating  default
# 1       1             1
# 2       1             7
# 1       0            33
# 3       1            62
# 2       0           243
# 4       1           263
# 5       1           558
# 6       1           960
# 3       0          1182
# 6       0          1663
# 4       0          2475
# 5       0          2553
# Name: default, dtype: int64

# %%
Loans_df['ratio_income_Totdebt'] = Loans_df['income']/Loans_df['total_debt_outstanding']
Loans_df['ratio_income_loan_amt'] = Loans_df['income']/Loans_df['loan_amt_outstanding']

# %%
Loans_df
# Out:
#       customer_id  credit_lines_outstanding  loan_amt_outstanding  \
# 0         8153374                         0           5221.545193
# 1         7442532                         5           1958.928726
# 2         2256073                         0           3363.009259
# 3         4885975                         0           4766.648001
# 4         4700614                         1           1345.827718
# ...           ...                       ...                   ...
# 9995      3972488                         0           3033.647103
# 9996      6184073                         1           4146.239304
# 9997      6694516                         2           3088.223727
# 9998      3942961                         0           3288.901666
# 9999      5533570                         1           1917.652480
#
#       total_debt_outstanding       income  years_employed  fico_score  \
# 0                3915.471226  78039.38546               5         605
# 1                8228.752520  26648.43525               2         572
# 2                2027.830850  65866.71246               4         602
# 3                2501.730397  74356.88347               5         612
# 4                1768.826187  23448.32631               6         631
# ...                      ...          ...             ...         ...
# 9995             2553.733144  42691.62787               5         697
# 9996             5458.163525  79969.50521               8         615
# 9997             4813.090925  38192.67591               5         596
# 9998             1043.099660  50929.37206               2         647
# 9999             3050.248203  30611.62821               6         757
#
#       default  Rating  ratio_income_Totdebt  ratio_income_loan_amt
# 0           0       5             19.931033              14.945650
# 1           1       6              3.238454              13.603576
# 2           0       5             32.481364              19.585647
# 3           0       5             29.722181              15.599407
# 4           0       5             13.256433              17.422978
# ...       ...     ...                   ...                    ...
# 9995        0       4             16.717341              14.072707
# 9996        0       5             14.651358              19.287238
# 9997        0       6              7.935166              12.367199
# 9998        0       5             48.825030              15.485222
# 9999        0       2             10.035783              15.963074
#
# [10000 rows x 11 columns]

# %% [markdown]
# # Predicting the PD (probability of default) for the borrowers using new ratings

# %%
Loans_df[['default','Rating']]
# Out:
#       default  Rating
# 0           0       5
# 1           1       6
# 2           0       5
# 3           0       5
# 4           0       5
# ...       ...     ...
# 9995        0       4
# 9996        0       5
# 9997        0       6
# 9998        0       5
# 9999        0       2
#
# [10000 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, recall_score, roc_auc_score

# %%
X = Loans_df.drop(['default','fico_score','customer_id'], axis=1)
Y = Loans_df['default']
id_users = Loans_df['customer_id']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=.7, random_state=123)

# %%
# Create, train, and fit a logistic regression model
from sklearn.linear_model import LogisticRegression
clf_logistic = LogisticRegression(solver='lbfgs').fit(X_train, np.ravel(Y_train))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Create predictions of probability for loan status using test data
# .predict_proba creates an array of probabilities of default: [[non-defualt-0, default-1]]
lr_preds = clf_logistic.predict_proba(X_test)

# %%
# # Create dataframes of predictions and true labels
lr_preds_df = pd.DataFrame(lr_preds[:,1][0:], columns = ['lr_pred_PD'])
true_df = Y_test

# %%
# Concatenate and print the two data frames for comparison
print(pd.concat([true_df.reset_index(drop = True), lr_preds_df], axis = 1))
# Out:
#       default    lr_pred_PD
# 0           0  2.044344e-01
# 1           0  9.963235e-09
# 2           0  1.450118e-12
# 3           0  3.161683e-07
# 4           0  1.325802e-06
# ...       ...           ...
# 6995        1  5.090270e-01
# 6996        0  1.285887e-09
# 6997        0  1.531234e-13
# 6998        0  7.605788e-11
# 6999        0  1.332625e-08
#
# [7000 rows x 2 columns]

# %%
# Reassign loan status based on the threshold and print the predictions
lr_preds_df['lr_pred_loan_status_60'] = lr_preds_df['lr_pred_PD'].apply(lambda x: 1 if x > 0.60 else 0)
print("Non-Default / Default predictions at 60% Threshhold: ")
print(lr_preds_df['lr_pred_loan_status_60'].value_counts())
# Out:
# Non-Default / Default predictions at 60% Threshhold:
# 0    5766
# 1    1234
# Name: lr_pred_loan_status_60, dtype: int64

# %%
Y_test.value_counts()
# Out:
# 0    5723
# 1    1277
# Name: default, dtype: int64

# %%
# Print the confusion matrix
from sklearn.metrics import confusion_matrix
print("Confusion Matrix at 60% Threshhold: ")
print(confusion_matrix(Y_test, lr_preds_df['lr_pred_loan_status_60']))
# Out:
# Confusion Matrix at 60% Threshhold:
# [[5716    7]
#  [  50 1227]]

# %%
# Print the classification report
from sklearn.metrics import classification_report
target_names = ['Non-Default', 'Default']
print(classification_report(Y_test, lr_preds_df['lr_pred_loan_status_60'], target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#  Non-Default       0.99      1.00      1.00      5723
#      Default       0.99      0.96      0.98      1277
#
#     accuracy                           0.99      7000
#    macro avg       0.99      0.98      0.99      7000
# weighted avg       0.99      0.99      0.99      7000

# %%
# Print the accuracy score the model
print(clf_logistic.score(X_test, Y_test))
# Out:
# 0.9934285714285714

# %%
# Plot the ROC curve of the probabilities of default
from sklearn.metrics import roc_curve

# %%
lr_prob_default = lr_preds[:, 1]
fallout, sensitivity, thresholds = roc_curve(Y_test, lr_prob_default)
plt.plot(fallout, sensitivity, color = 'darkorange')
plt.plot([0, 1], [0, 1], linestyle='--')
plt.title("ROC Chart for LR on PD")
plt.xlabel("Fall-out")
plt.ylabel("Sensitivity")
plt.show()

# %% [markdown]
# #  Fitting the Model to entire dataset

# %%
Prob_to_default = clf_logistic.predict_proba(X)

# %%
prob_data = pd.DataFrame(Prob_to_default[:,1][0:].round(decimals = 2), columns = ['Probability _to_Default'])

# %%
prob_data
# Out:
#       Probability _to_Default
# 0                         0.0
# 1                         1.0
# 2                         0.0
# 3                         0.0
# 4                         0.0
# ...                       ...
# 9995                      0.0
# 9996                      0.0
# 9997                      0.0
# 9998                      0.0
# 9999                      0.0
#
# [10000 rows x 1 columns]

# %%
X = pd.concat([id_users,X,Y, prob_data], axis = 1)

# %%
X
# Out:
#       customer_id  credit_lines_outstanding  loan_amt_outstanding  \
# 0         8153374                         0           5221.545193
# 1         7442532                         5           1958.928726
# 2         2256073                         0           3363.009259
# 3         4885975                         0           4766.648001
# 4         4700614                         1           1345.827718
# ...           ...                       ...                   ...
# 9995      3972488                         0           3033.647103
# 9996      6184073                         1           4146.239304
# 9997      6694516                         2           3088.223727
# 9998      3942961                         0           3288.901666
# 9999      5533570                         1           1917.652480
#
#       total_debt_outstanding       income  years_employed  Rating  \
# 0                3915.471226  78039.38546               5       5
# 1                8228.752520  26648.43525               2       6
# 2                2027.830850  65866.71246               4       5
# 3                2501.730397  74356.88347               5       5
# 4                1768.826187  23448.32631               6       5
# ...                      ...          ...             ...     ...
# 9995             2553.733144  42691.62787               5       4
# 9996             5458.163525  79969.50521               8       5
# 9997             4813.090925  38192.67591               5       6
# 9998             1043.099660  50929.37206               2       5
# 9999             3050.248203  30611.62821               6       2
#
#       ratio_income_Totdebt  ratio_income_loan_amt  default  \
# 0                19.931033              14.945650        0
# 1                 3.238454              13.603576        1
# 2                32.481364              19.585647        0
# 3                29.722181              15.599407        0
# 4                13.256433              17.422978        0
# ...                    ...                    ...      ...
# 9995             16.717341              14.072707        0
# 9996             14.651358              19.287238        0
# 9997              7.935166              12.367199        0
# 9998             48.825030              15.485222        0
# 9999             10.035783              15.963074        0
#
#       Probability _to_Default
# 0                         0.0
# 1                         1.0
# 2                         0.0
# 3                         0.0
# 4                         0.0
# ...                       ...
# 9995                      0.0
# 9996                      0.0
# 9997                      0.0
# 9998                      0.0
# 9999                      0.0
#
# [10000 rows x 11 columns]

# %% [markdown]
# # Predicting the PD (probability of default) for the borrowers using only new ratings

# %%
X = Loans_df['Rating'].to_numpy().reshape(-1,1)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=.7, random_state=123)

# %%
# Create, train, and fit a logistic regression model
from sklearn.linear_model import LogisticRegression
clf_logistic = LogisticRegression(solver='lbfgs').fit(X_train, np.ravel(Y_train))

# %%
# Create predictions of probability for loan status using test data
# .predict_proba creates an array of probabilities of default: [[non-defualt-0, default-1]]
lr_preds = clf_logistic.predict_proba(X_test)

# %%
# # Create dataframes of predictions and true labels
lr_preds_df = pd.DataFrame(lr_preds[:,1][0:], columns = ['lr_pred_PD'])
true_df = Y_test

# %%
# Concatenate and print the two data frames for comparison
print(pd.concat([true_df.reset_index(drop = True), lr_preds_df], axis = 1))
# Out:
#       default  lr_pred_PD
# 0           0    0.372445
# 1           0    0.372445
# 2           0    0.092889
# 3           0    0.092889
# 4           0    0.017362
# ...       ...         ...
# 6995        1    0.197768
# 6996        0    0.092889
# 6997        0    0.197768
# 6998        0    0.092889
# 6999        0    0.197768
#
# [7000 rows x 2 columns]

# %%
# Print the accuracy score the model
print(clf_logistic.score(X_test, Y_test))
# Out:
# 0.8175714285714286

# %%
lr_prob_default = lr_preds[:, 1]
fallout, sensitivity, thresholds = roc_curve(Y_test, lr_prob_default)
plt.plot(fallout, sensitivity, color = 'darkorange')
plt.plot([0, 1], [0, 1], linestyle='--')
plt.title("ROC Chart for LR on PD")
plt.xlabel("Fall-out")
plt.ylabel("Sensitivity")
plt.show()

# %% [markdown]
# #  Fitting the Model to entire dataset

# %%
Prob_to_default = clf_logistic.predict_proba(X)

# %%
prob_data = pd.DataFrame(Prob_to_default[:,1][0:].round(decimals = 2), columns = ['Probability _to_Default'])

# %%
X = pd.concat([Loans_df, prob_data], axis = 1)

# %%
X
# Out:
#       customer_id  credit_lines_outstanding  loan_amt_outstanding  \
# 0         8153374                         0           5221.545193
# 1         7442532                         5           1958.928726
# 2         2256073                         0           3363.009259
# 3         4885975                         0           4766.648001
# 4         4700614                         1           1345.827718
# ...           ...                       ...                   ...
# 9995      3972488                         0           3033.647103
# 9996      6184073                         1           4146.239304
# 9997      6694516                         2           3088.223727
# 9998      3942961                         0           3288.901666
# 9999      5533570                         1           1917.652480
#
#       total_debt_outstanding       income  years_employed  fico_score  \
# 0                3915.471226  78039.38546               5         605
# 1                8228.752520  26648.43525               2         572
# 2                2027.830850  65866.71246               4         602
# 3                2501.730397  74356.88347               5         612
# 4                1768.826187  23448.32631               6         631
# ...                      ...          ...             ...         ...
# 9995             2553.733144  42691.62787               5         697
# 9996             5458.163525  79969.50521               8         615
# 9997             4813.090925  38192.67591               5         596
# 9998             1043.099660  50929.37206               2         647
# 9999             3050.248203  30611.62821               6         757
#
#       default  Rating  ratio_income_Totdebt  ratio_income_loan_amt  \
# 0           0       5             19.931033              14.945650
# 1           1       6              3.238454              13.603576
# 2           0       5             32.481364              19.585647
# 3           0       5             29.722181              15.599407
# 4           0       5             13.256433              17.422978
# ...       ...     ...                   ...                    ...
# 9995        0       4             16.717341              14.072707
# 9996        0       5             14.651358              19.287238
# 9997        0       6              7.935166              12.367199
# 9998        0       5             48.825030              15.485222
# 9999        0       2             10.035783              15.963074
#
#       Probability _to_Default
# 0                        0.20
# 1                        0.37
# 2                        0.20
# 3                        0.20
# 4                        0.20
# ...                       ...
# 9995                     0.09
# 9996                     0.20
# 9997                     0.37
# 9998                     0.20
# 9999                     0.02
#
# [10000 rows x 12 columns]

# %% [markdown]
# Model built in this way clearly understimate risk of default for low fico scores or low income/total debt ratio , anyway
# it could be used to get a "at priori" probability of default for a specific rating category
